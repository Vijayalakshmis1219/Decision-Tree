# %%
import pandas as pd
from pandas import DataFrame

# %%
df_tennis=pd.read_csv('Exp4.csv')
print(df_tennis)
# Out:
#     Day   Outlook Temperaure Humidity     Wind Play Tennis
# 0     1     sunny        hot     High     weak          no
# 1     2     sunny        hot     High   strong          no
# 2     3  overcast        hot     High     weak         yes
# 3     4      rain       mild     High     weak         yes
# 4     5      rain       mild   Normal     weak         yes
# 5     6      rain       mild   Normal   strong          no
# 6     7  overcast       mild   Normal   strong         yes
# 7     8     sunny       mild     high     weak          no
# 8     9     sunny       mild   Normal     weak         yes
# 9    10      rain       mild   Normal     weak         yes
# 10   11     sunny       mild   Normal   strong         yes
# 11   12  overcast       mild     high   strong         yes
# 12   13  overcast       mild   Normal     weak         yes
# 13   14      rain       mild     high   strong          no

# %%
def entropy(probs):
  import math
  return sum([-prob*math.log(prob,2) for prob in probs])
def entropy_of_list(a_list):
  from collections import Counter
  cnt=Counter(x for x in a_list)
  num_instances=len(a_list)
  probs=[x/num_instances for x in cnt.values()]
  return entropy(probs)
total_entropy=entropy_of_list(df_tennis['Play Tennis'])
print("Total entropy of tennis played:",total_entropy)
# Out:
# Total entropy of tennis played: 0.9402859586706309

# %%
def information_gain(df,split_attribute_name,target_attribute_name,trace=0):
  print("Information gain calculation of",split_attribute_name)
  print("target_attribute_name:",target_attribute_name)
  #df_split = df.groupby(split_attribute_name)
  df_split=df.groupby(split_attribute_name)
  for name,group in df_split:
    print("Namee:",name)
    print("Group:",group)
  nobs=len(df.index)*1.0
  print("NOBS",nobs)
  df_agg_ent=df_split.agg({target_attribute_name:[entropy_of_list,lambda x:len(x)/nobs]})[target_attribute_name]
  print("df_agg_ent",df_agg_ent)
  df_agg_ent.columns=['Entropy','Prob1']
  avg_info=sum(df_agg_ent['Entropy']*df_agg_ent['Prob1'])
  old_entropy=entropy_of_list(df[target_attribute_name])
  return old_entropy-avg_info
print('Info-gain for Outlook is :'+str(information_gain(df_tennis,'Outlook','Play Tennis')),"\n")
# Out:
# Information gain calculation of Outlook
# target_attribute_name: Play Tennis
# Namee: overcast
# Group:     Day   Outlook Temperaure Humidity    Wind Play Tennis
# 2     3  overcast        hot     High    weak         yes
# 6     7  overcast       mild   Normal  strong         yes
# 11   12  overcast       mild     high  strong         yes
# 12   13  overcast       mild   Normal    weak         yes
# Namee: rain
# Group:     Day Outlook Temperaure Humidity     Wind Play Tennis
# 3     4    rain       mild     High     weak         yes
# 4     5    rain       mild   Normal     weak         yes
# 5     6    rain       mild   Normal   strong          no
# 9    10    rain       mild   Normal     weak         yes
# 13   14    rain       mild     high   strong          no
# Namee: sunny
# Group:     Day Outlook Temperaure Humidity    Wind Play Tennis
# 0     1   sunny        hot     High    weak          no
# 1     2   sunny        hot     High  strong          no
# 7     8   sunny       mild     high    weak          no
# 8     9   sunny       mild   Normal    weak         yes
# 10   11   sunny       mild   Normal  strong         yes
# NOBS 14.0
# df_agg_ent           entropy_of_list  <lambda_0>
# Outlook
# overcast         0.000000    0.285714
# rain             0.970951    0.357143
# sunny            0.970951    0.357143
# Info-gain for Outlook is :0.2467498197744391
